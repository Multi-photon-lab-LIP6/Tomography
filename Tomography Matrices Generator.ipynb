# %%
import numpy as np
import functools as ft
import itertools
import os
from NestedForLoop import get_iterator

# %%
qubit_number=4
Pauli=np.asarray([
        [[1,0],
        [0,1]],


        [[0,1],
        [1,0]],


        [[0,-1j],
        [1j,0]],


        [[1,0],
        [0,-1]]])


states=np.asarray([
    [1,1]/np.sqrt(2),
    [1,-1]/np.sqrt(2),
    [1,1j]/np.sqrt(2),
    [1,-1j]/np.sqrt(2),
    [1,0],
    [0,1],
])

# %%
def get_proj_iterator(N_qubit, basis):
    d={"x": [[1,1]/np.sqrt(2),
             [1,-1]/np.sqrt(2)],
       "y": [[1,1j]/np.sqrt(2),
            [1,-1j]/np.sqrt(2)],
       "z": [[1,0],[0,1]]
      }
    
    basis_order = get_iterator(3, N_qubit)
    projectors_order = get_iterator(2, N_qubit)
    columns=[]
    
    
    character_matrix=[]
    for i in basis_order:
        string=""
        for j in i:
            string=string+basis[j]
        lines=[]    
        for k in projectors_order:
            o=0
            vect=[]
            for n in k:
                vect.append(d[string[o]][n])
                o=o+1
            lines.append(vect)    
        character_matrix.append(lines)         
        columns.append(string)   
        
    return character_matrix

# %%
import numpy as np
import itertools
import functools as ft

qubit_number=4
Pauli=np.asarray([
        [[1,0],
        [0,1]],


        [[0,1],
        [1,0]],


        [[0,-1j],
        [1j,0]],


        [[1,0],
        [0,-1]]])


states=np.asarray([
    [1,1]/np.sqrt(2),
    [1,-1]/np.sqrt(2),
    [1,1j]/np.sqrt(2),
    [1,-1j]/np.sqrt(2),
    [1,0],
    [0,1],
])

def get_proj_iterator(N_qubit, basis):
    d={"x": [[1,1]/np.sqrt(2),
             [1,-1]/np.sqrt(2)],
       "y": [[1,1j]/np.sqrt(2),
            [1,-1j]/np.sqrt(2)],
       "z": [[1,0],[0,1]]
      }
    
    basis_order = get_iterator(3, N_qubit)
    projectors_order = get_iterator(2, N_qubit)
    columns=[]
    
    
    character_matrix=[]
    for i in basis_order:
        string=""
        for j in i:
            string=string+basis[j]
        lines=[]    
        for k in projectors_order:
            o=0
            vect=[]
            for n in k:
                vect.append(d[string[o]][n])
                o=o+1
            lines.append(vect)    
        character_matrix.append(lines)         
        columns.append(string)   
        
    return character_matrix 

basis=["x","y","z"]
v = get_proj_iterator(4, basis)


projectors2 = []
v=np.reshape(v,[3**qubit_number*2**qubit_number,qubit_number,2])
for i in list(v):
    projectors2.append(np.outer(ft.reduce(np.kron, i),np.conjugate(np.transpose(ft.reduce(np.kron, i)))))
    
    
observables = []
perm = itertools.product(Pauli, repeat=qubit_number)
for i in list(perm):
    observables.append(ft.reduce(np.kron, i)) 

psi=np.zeros((len(observables[1:]),len(projectors2)))
# psi_aux=np.zeros((3*qubit_number,2**qubit_number,4*qubit_number-1))

for i in range(len(observables[1:])):
    for j in range(len(projectors2)):
        psi[i][j]=np.trace(projectors2[j]@observables[i+1])/(2**qubit_number)
psi_aux=np.reshape(np.transpose(psi),[3**qubit_number,2**qubit_number,4**qubit_number-1]) 

invPSI=np.linalg.inv(psi@psi.transpose())

# %%
working_dir = os.getcwd()
np.save(working_dir+'\SavedVariables\X_matrix'+str(qubit_number), psi_matrix)
np.save(working_dir+'\SavedVariables\invXtX_matrix'+str(qubit_number), invPSI_matrix)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\S'
# <>:3: SyntaxWarning: invalid escape sequence '\S'
# <>:2: SyntaxWarning: invalid escape sequence '\S'
# <>:3: SyntaxWarning: invalid escape sequence '\S'
# C:\Users\QILIP6\AppData\Local\Temp\ipykernel_23568\3078998118.py:2: SyntaxWarning: invalid escape sequence '\S'
#   np.save(working_dir+'\SavedVariables\X_matrix'+str(qubit_number), psi_matrix)
# C:\Users\QILIP6\AppData\Local\Temp\ipykernel_23568\3078998118.py:3: SyntaxWarning: invalid escape sequence '\S'
#   np.save(working_dir+'\SavedVariables\invXtX_matrix'+str(qubit_number), invPSI_matrix)

# %%
*4
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\S'
# <>:1: SyntaxWarning: invalid escape sequence '\S'
# C:\Users\QILIP6\AppData\Local\Temp\ipykernel_23568\1681416759.py:1: SyntaxWarning: invalid escape sequence '\S'
#   np.load(working_dir+'\SavedVariables\Pauli4.npy')*4
# array([[[ 0.25+0.j  ,  0.  +0.j  ,  0.  +0.j  , ...,  0.  +0.j  ,
#           0.  +0.j  ,  0.  +0.j  ],
#         [ 0.  +0.j  ,  0.25+0.j  ,  0.  +0.j  , ...,  0.  +0.j  ,
#           0.  +0.j  ,  0.  +0.j  ],
#         [ 0.  +0.j  ,  0.  +0.j  ,  0.25+0.j  , ...,  0.  +0.j  ,
#           0.  +0.j  ,  0.  +0.j  ],
#         ...,
#         [ 0.  +0.j  ,  0.  +0.j  ,  0.  +0.j  , ...,  0.25+0.j  ,
#           0.  +0.j  ,  0.  +0.j  ],
#         [ 0.  +0.j  ,  0.  +0.j  ,  0.  +0.j  , ...,  0.  +0.j  ,
#           0.25+0.j  ,  0.  +0.j  ],
#         [ 0.  +0.j  ,  0.  +0.j  ,  0.  +0.j  , ...,  0.  +0.j  ,
#           0.  +0.j  ,  0.25+0.j  ]],
#
#        [[ 0.  +0.j  ,  0.25+0.j  ,  0.  +0.j  , ...,  0.  +0.j  ,
#           0.  +0.j  ,  0.  +0.j  ],
#         [ 0.25+0.j  ,  0.  +0.j  ,  0.  +0.j  , ...,  0.  +0.j  ,
#           0.  +0.j  ,  0.  +0.j  ],
#         [ 0.  +0.j  ,  0.  +0.j  ,  0.  +0.j  , ...,  0.  +0.j  ,
#           0.  +0.j  ,  0.  +0.j  ],
#         ...,
#         [ 0.  +0.j  ,  0.  +0.j  ,  0.  +0.j  , ...,  0.  +0.j  ,
#           0.  +0.j  ,  0.  +0.j  ],
#         [ 0.  +0.j  ,  0.  +0.j  ,  0.  +0.j  , ...,  0.  +0.j  ,
#           0.  +0.j  ,  0.25+0.j  ],
#         [ 0.  +0.j  ,  0.  +0.j  ,  0.  +0.j  , ...,  0.  +0.j  ,
#           0.25+0.j  ,  0.  +0.j  ]],
#
#        [[ 0.  +0.j  ,  0.  -0.25j,  0.  +0.j  , ...,  0.  +0.j  ,
#           0.  +0.j  ,  0.  +0.j  ],
#         [ 0.  +0.25j,  0.  +0.j  ,  0.  +0.j  , ...,  0.  +0.j  ,
#           0.  +0.j  ,  0.  +0.j  ],
#         [ 0.  +0.j  ,  0.  +0.j  ,  0.  +0.j  , ...,  0.  +0.j  ,
#           0.  +0.j  ,  0.  +0.j  ],
#         ...,
#         [ 0.  +0.j  ,  0.  +0.j  ,  0.  +0.j  , ...,  0.  +0.j  ,
#           0.  +0.j  ,  0.  +0.j  ],
#         [ 0.  +0.j  ,  0.  +0.j  ,  0.  +0.j  , ...,  0.  +0.j  ,
#           0.  +0.j  ,  0.  -0.25j],
#         [ 0.  +0.j  ,  0.  +0.j  ,  0.  +0.j  , ...,  0.  +0.j  ,
#           0.  +0.25j,  0.  +0.j  ]],
#
#        ...,
#
#        [[ 0.  +0.j  ,  0.25+0.j  ,  0.  +0.j  , ...,  0.  +0.j  ,
#           0.  +0.j  ,  0.  +0.j  ],
#         [ 0.25+0.j  ,  0.  +0.j  ,  0.  +0.j  , ...,  0.  +0.j  ,
#           0.  +0.j  ,  0.  +0.j  ],
#         [ 0.  +0.j  ,  0.  +0.j  ,  0.  +0.j  , ...,  0.  +0.j  ,
#           0.  +0.j  ,  0.  +0.j  ],
#         ...,
#         [ 0.  +0.j  ,  0.  +0.j  ,  0.  +0.j  , ...,  0.  +0.j  ,
#           0.  +0.j  ,  0.  +0.j  ],
#         [ 0.  +0.j  ,  0.  +0.j  ,  0.  +0.j  , ...,  0.  +0.j  ,
#           0.  +0.j  , -0.25+0.j  ],
#         [ 0.  +0.j  ,  0.  +0.j  ,  0.  +0.j  , ...,  0.  +0.j  ,
#          -0.25+0.j  ,  0.  +0.j  ]],
#
#        [[ 0.  +0.j  ,  0.  -0.25j,  0.  +0.j  , ...,  0.  +0.j  ,
#           0.  +0.j  ,  0.  +0.j  ],
#         [ 0.  +0.25j,  0.  +0.j  ,  0.  +0.j  , ...,  0.  +0.j  ,
#           0.  +0.j  ,  0.  +0.j  ],
#         [ 0.  +0.j  ,  0.  +0.j  ,  0.  +0.j  , ...,  0.  +0.j  ,
#           0.  +0.j  ,  0.  +0.j  ],
#         ...,
#         [ 0.  +0.j  ,  0.  +0.j  ,  0.  +0.j  , ...,  0.  +0.j  ,
#           0.  +0.j  ,  0.  +0.j  ],
#         [ 0.  +0.j  ,  0.  +0.j  ,  0.  +0.j  , ...,  0.  +0.j  ,
#           0.  +0.j  ,  0.  +0.25j],
#         [ 0.  +0.j  ,  0.  +0.j  ,  0.  +0.j  , ...,  0.  +0.j  ,
#           0.  -0.25j,  0.  +0.j  ]],
#
#        [[ 0.25+0.j  ,  0.  +0.j  ,  0.  +0.j  , ...,  0.  +0.j  ,
#           0.  +0.j  ,  0.  +0.j  ],
#         [ 0.  +0.j  , -0.25+0.j  ,  0.  +0.j  , ...,  0.  +0.j  ,
#           0.  +0.j  ,  0.  +0.j  ],
#         [ 0.  +0.j  ,  0.  +0.j  , -0.25+0.j  , ...,  0.  +0.j  ,
#           0.  +0.j  ,  0.  +0.j  ],
#         ...,
#         [ 0.  +0.j  ,  0.  +0.j  ,  0.  +0.j  , ..., -0.25+0.j  ,
#           0.  +0.j  ,  0.  +0.j  ],
#         [ 0.  +0.j  ,  0.  +0.j  ,  0.  +0.j  , ...,  0.  +0.j  ,
#          -0.25+0.j  ,  0.  +0.j  ],
#         [ 0.  +0.j  ,  0.  +0.j  ,  0.  +0.j  , ...,  0.  +0.j  ,
#           0.  +0.j  ,  0.25+0.j  ]]])
